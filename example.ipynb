# %%
import numpy as np

from plt_colors.style import *

# %%
for i, color in enumerate(chart_colors):
    y = [i for _ in range(100)]
    plt.plot(y)

# %%
x = np.arange(0, 10, 0.01)
for i in range(6 * 5):
    y = np.sin(x + i/10) * i/100
    plt.plot(x, y)
